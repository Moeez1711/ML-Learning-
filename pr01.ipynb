# %% [markdown]
# <a href="https://colab.research.google.com/github/Moeez1711/Aipixel-Company-portfolio/blob/main/pr01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"hellow world"
# Out:
# 'hellow world'

# %%
3+8
# Out:
# 11
